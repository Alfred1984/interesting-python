# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pyecharts import Bar, Line, Overlap

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点
# %matplotlib inline

# %%
data = pd.read_csv('NationalNames.csv')

# %%
data.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924665 entries, 0 to 1924664
# Data columns (total 5 columns):
# Id        int64
# Name      object
# Year      int64
# Gender    object
# Count     int64
# dtypes: int64(3), object(2)
# memory usage: 73.4+ MB

# %% [markdown]
# ## 1. 2010-2017年，Top15的男生、女生英文名

# %% [markdown]
# ### - 男生

# %%
top15_boy = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M'), :].groupby('Name').Count.sum().nlargest(15)
boy_total = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M'), :].groupby('Name').Count.sum().sum()

# %%
name = list(top15_boy.index)
value = list(top15_boy.values)
wordcloud = WordCloud(width=800, height=450,background_color='#f2eada')  # feeeed
wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="57d90db6021c4904a8f5befebe6969cc" style="width:800px;height:450px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_57d90db6021c4904a8f5befebe6969cc = echarts.init(document.getElementById('57d90db6021c4904a8f5befebe6969cc'), null, {renderer: 'canvas'});
# var option_57d90db6021c4904a8f5befebe6969cc = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7190524,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Noah",
#                     "value": 145195.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,145,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jacob",
#                     "value": 140091.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,61,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mason",
#                     "value": 133535.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,94,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Liam",
#                     "value": 133019.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,35,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "William",
#                     "value": 131241.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,139,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Ethan",
#                     "value": 125561.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,47,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Michael",
#                     "value": 122265.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,83,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Alexander",
#                     "value": 118376.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,35,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "James",
#                     "value": 112387.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,133,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Daniel",
#                     "value": 111658.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,133,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Elijah",
#                     "value": 110075.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,137,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Aiden",
#                     "value": 109852.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,39,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jayden",
#                     "value": 109122.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,18,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Benjamin",
#                     "value": 107648.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,11,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Matthew",
#                     "value": 105429.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,67,118)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#f2eada",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_57d90db6021c4904a8f5befebe6969cc.setOption(option_57d90db6021c4904a8f5befebe6969cc);
#
#     });
# </script>

# %%
data_top15_boy = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M') & 
                          (data['Name']).isin(list(top15_boy.index)), :]

# %%
data_top15_boy.sort_values(by = ['Year', 'Count'], ascending=False, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.set(font_scale=1.4)
g = sns.FacetGrid(data_top15_boy, col="Name", col_wrap=3)

g = g.map(plt.plot, "Year", "Count",color="c",marker=".")
g.set(axis_bgcolor='#f2eada')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/artist.py:896: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# ### - 女生

# %%
top15_girl = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F'), :].groupby('Name').Count.sum().nlargest(15)

# %%
list(data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F'), :].groupby('Name').Count.sum().nlargest(30).index)
# Out:
# ['Emma',
#  'Sophia',
#  'Olivia',
#  'Isabella',
#  'Ava',
#  'Mia',
#  'Emily',
#  'Abigail',
#  'Madison',
#  'Elizabeth',
#  'Charlotte',
#  'Chloe',
#  'Ella',
#  'Amelia',
#  'Avery',
#  'Sofia',
#  'Evelyn',
#  'Harper',
#  'Addison',
#  'Grace',
#  'Natalie',
#  'Victoria',
#  'Lily',
#  'Aubrey',
#  'Lillian',
#  'Zoey',
#  'Hannah',
#  'Brooklyn',
#  'Layla',
#  'Samantha']

# %%
name = list(top15_girl.index)
value = list(top15_girl.values)
wordcloud = WordCloud(width=800, height=500,background_color='#feeeed')  # feeeed
wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="966072d074634df28d6ffebb4e28c421" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_966072d074634df28d6ffebb4e28c421 = echarts.init(document.getElementById('966072d074634df28d6ffebb4e28c421'), null, {renderer: 'canvas'});
# var option_966072d074634df28d6ffebb4e28c421 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1896871,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Emma",
#                     "value": 158573.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,100,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Sophia",
#                     "value": 152936.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,148,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Olivia",
#                     "value": 147486.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,79,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Isabella",
#                     "value": 142064.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,90,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Ava",
#                     "value": 125937.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,90,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mia",
#                     "value": 103580.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,80,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emily",
#                     "value": 100414.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,139,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Abigail",
#                     "value": 99356.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,149,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Madison",
#                     "value": 84803.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(142,122,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Elizabeth",
#                     "value": 77233.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(109,62,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charlotte",
#                     "value": 76031.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,160,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chloe",
#                     "value": 71994.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,84,84)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Ella",
#                     "value": 69455.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,12,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amelia",
#                     "value": 68291.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,59,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Avery",
#                     "value": 67348.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,48,4)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#feeeed",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_966072d074634df28d6ffebb4e28c421.setOption(option_966072d074634df28d6ffebb4e28c421);
#
#     });
# </script>

# %%
data_top15_girl = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F') & 
                          (data['Name']).isin(list(top15_girl.index)), :]

data_top15_girl.sort_values(by = ['Year', 'Count'], ascending=False, inplace=True)

sns.set(font_scale=1.4)
g = sns.FacetGrid(data_top15_girl, col="Name", col_wrap=3)

g = g.map(plt.plot, "Year", "Count",color="c",marker=".")
g.set(axis_bgcolor='#feeeed')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/artist.py:896: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %% [markdown]
# ## 2. 每个年代，最流行的英文名字
# - 1920-2017

# %%
data_decades = data[data['Year']>=1920]
data_decades['decade'] = pd.cut(data_decades['Year'], [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2018], 
                                labels = ['20后','30后','40后', '50后','60后','70后','80后','90后','00后','10后'],right=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
decade = data_decades.groupby(['decade', 'Gender', 'Name']).Count.sum().groupby(level=[0,1]).nlargest(1)

# %%
decade_boy_count = decade.iloc[decade.index.get_level_values(3)=='M'].reset_index(level=[0,1,3], drop=True)
decade_boy_total = data_decades[data_decades['Gender']=='M'].groupby('decade').Count.sum()
decade_boy_pct = (decade_boy_count/decade_boy_total*100).round(2)
ax = decade_boy_pct.plot.barh(title='各年代最流行的男性名字')
ax.set_ylabel('')
ax.set_xlabel('百分比')
ax.set(axis_bgcolor='#f2eada')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/artist.py:896: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)
# [None]

# %%
decade_girl_count = decade.iloc[decade.index.get_level_values(3)=='F'].reset_index(level=[0,1,3], drop=True)
decade_girl_total = data_decades[data_decades['Gender']=='F'].groupby('decade').Count.sum()
decade_girl_pct = (decade_girl_count/decade_girl_total*100).round(2)
ax = decade_girl_pct.plot.barh(title='各年代最流行的女性名字')
ax.set_ylabel('')
ax.set_xlabel('百分比')
ax.set(axis_bgcolor='#feeeed')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/artist.py:896: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)
# [None]

# %% [markdown]
# ## 3. 以前很流行，现在不流行的名字

# %% [markdown]
# ### -男

# %%
data_popular_former = data[(data['Year'] < 1950) & (data['Count'] > 10500) & (data['Gender'] == 'M')]
data_not_popular_now = data[(data['Year'] > 2000) & (data['Count'] < 1000) & (data['Gender'] == 'M')]

# %%
boys_names_popular_former = list(set(list(data_popular_former.Name.unique())) & set(list(data_not_popular_now.Name.unique())))

# %%
boys_names_popular_former_data = data[(data['Name'].isin(boys_names_popular_former)) & (data['Year']>=1920) & (data['Gender']=='M')]

# %%
attr = list(range(1920, 2018))
line = Line("",width=800, height=600)
for name in boys_names_popular_former:
    v = list(boys_names_popular_former_data[boys_names_popular_former_data['Name']==name].Count.values)
    line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5e5306bc5c614972a32acc8ebcaca579" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5e5306bc5c614972a32acc8ebcaca579 = echarts.init(document.getElementById('5e5306bc5c614972a32acc8ebcaca579'), null, {renderer: 'canvas'});
# var option_5e5306bc5c614972a32acc8ebcaca579 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5610706,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Gregory",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 180.0,
#                 184.0,
#                 220.0,
#                 191.0,
#                 226.0,
#                 213.0,
#                 243.0,
#                 242.0,
#                 260.0,
#                 237.0,
#                 248.0,
#                 256.0,
#                 283.0,
#                 254.0,
#                 329.0,
#                 368.0,
#                 393.0,
#                 507.0,
#                 536.0,
#                 598.0,
#                 756.0,
#                 823.0,
#                 1026.0,
#                 1133.0,
#                 1307.0,
#                 2475.0,
#                 5671.0,
#                 9324.0,
#                 9724.0,
#                 10980.0,
#                 13312.0,
#                 14102.0,
#                 15207.0,
#                 16149.0,
#                 17611.0,
#                 19809.0,
#                 21082.0,
#                 21447.0,
#                 19790.0,
#                 19873.0,
#                 20316.0,
#                 21354.0,
#                 21964.0,
#                 21432.0,
#                 19889.0,
#                 18210.0,
#                 17008.0,
#                 15784.0,
#                 15405.0,
#                 16172.0,
#                 16291.0,
#                 14768.0,
#                 13060.0,
#                 11683.0,
#                 10834.0,
#                 10407.0,
#                 10062.0,
#                 10054.0,
#                 9351.0,
#                 9115.0,
#                 9265.0,
#                 8756.0,
#                 10150.0,
#                 9982.0,
#                 9690.0,
#                 9769.0,
#                 9534.0,
#                 9127.0,
#                 8629.0,
#                 8757.0,
#                 8376.0,
#                 7551.0,
#                 6493.0,
#                 5806.0,
#                 5135.0,
#                 4442.0,
#                 3993.0,
#                 3803.0,
#                 3429.0,
#                 3047.0,
#                 2838.0,
#                 2476.0,
#                 2277.0,
#                 2106.0,
#                 1968.0,
#                 1901.0,
#                 1833.0,
#                 1679.0,
#                 1556.0,
#                 1424.0,
#                 1286.0,
#                 1264.0,
#                 1227.0,
#                 1177.0,
#                 1106.0,
#                 982.0,
#                 921.0,
#                 881.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5610706
#         },
#         {
#             "type": "line",
#             "name": "Larry",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 440.0,
#                 491.0,
#                 491.0,
#                 518.0,
#                 577.0,
#                 723.0,
#                 806.0,
#                 837.0,
#                 1068.0,
#                 1269.0,
#                 1720.0,
#                 2146.0,
#                 2823.0,
#                 3251.0,
#                 4470.0,
#                 5977.0,
#                 7612.0,
#                 10320.0,
#                 12386.0,
#                 14528.0,
#                 17200.0,
#                 20130.0,
#                 22098.0,
#                 22968.0,
#                 22020.0,
#                 22824.0,
#                 28445.0,
#                 34935.0,
#                 33429.0,
#                 31809.0,
#                 31487.0,
#                 30558.0,
#                 28249.0,
#                 25204.0,
#                 24605.0,
#                 22820.0,
#                 22294.0,
#                 21912.0,
#                 20066.0,
#                 18417.0,
#                 15988.0,
#                 14578.0,
#                 12710.0,
#                 11674.0,
#                 10674.0,
#                 9405.0,
#                 8714.0,
#                 8330.0,
#                 8233.0,
#                 8285.0,
#                 8109.0,
#                 7762.0,
#                 6605.0,
#                 6082.0,
#                 5696.0,
#                 5311.0,
#                 4843.0,
#                 4839.0,
#                 4515.0,
#                 4393.0,
#                 4268.0,
#                 3952.0,
#                 3720.0,
#                 3382.0,
#                 3105.0,
#                 2947.0,
#                 2624.0,
#                 2501.0,
#                 2447.0,
#                 2338.0,
#                 2194.0,
#                 2073.0,
#                 1862.0,
#                 1780.0,
#                 1559.0,
#                 1401.0,
#                 1371.0,
#                 1239.0,
#                 1208.0,
#                 1255.0,
#                 1118.0,
#                 1030.0,
#                 952.0,
#                 950.0,
#                 898.0,
#                 828.0,
#                 791.0,
#                 962.0,
#                 823.0,
#                 782.0,
#                 811.0,
#                 715.0,
#                 659.0,
#                 580.0,

# %% [markdown]
# ### -女

# %%
data_popular_former = data[(data['Year'] < 1950) & (data['Count'] > 22500) & (data['Gender'] == 'F')]
data_not_popular_now = data[(data['Year'] > 2000) & (data['Count'] < 1000) & (data['Gender'] == 'F')]

# %%
girl_names_popular_former = list(set(list(data_popular_former.Name.unique())) & set(list(data_not_popular_now.Name.unique())))

# %%
girl_names_popular_former_data = data[(data['Name'].isin(girl_names_popular_former)) & (data['Year']>=1920) & (data['Gender']=='F')]

# %%
attr = list(range(1920, 2018))
line = Line("",width=800, height=600)
for name in girl_names_popular_former:
    v = list(girl_names_popular_former_data[girl_names_popular_former_data['Name']==name].Count.values)
    line.add(name, attr, v,legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ceae3b350819441cbdeed99f41ddd199" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ceae3b350819441cbdeed99f41ddd199 = echarts.init(document.getElementById('ceae3b350819441cbdeed99f41ddd199'), null, {renderer: 'canvas'});
# var option_ceae3b350819441cbdeed99f41ddd199 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 701862,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Patricia",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 2502.0,
#                 3381.0,
#                 3902.0,
#                 4799.0,
#                 6958.0,
#                 8095.0,
#                 8590.0,
#                 10553.0,
#                 12333.0,
#                 13624.0,
#                 15752.0,
#                 16468.0,
#                 17990.0,
#                 18629.0,
#                 20845.0,
#                 22876.0,
#                 23914.0,
#                 26838.0,
#                 27555.0,
#                 29706.0,
#                 32662.0,
#                 36901.0,
#                 39454.0,
#                 39623.0,
#                 36876.0,
#                 35839.0,
#                 46296.0,
#                 51278.0,
#                 46134.0,
#                 46330.0,
#                 47945.0,
#                 56441.0,
#                 53101.0,
#                 51013.0,
#                 49144.0,
#                 46221.0,
#                 43328.0,
#                 39275.0,
#                 37936.0,
#                 35219.0,
#                 32102.0,
#                 28870.0,
#                 26537.0,
#                 25369.0,
#                 26090.0,
#                 23555.0,
#                 20112.0,
#                 17748.0,
#                 15810.0,
#                 14953.0,
#                 13406.0,
#                 11464.0,
#                 9601.0,
#                 8475.0,
#                 8036.0,
#                 7050.0,
#                 6017.0,
#                 5905.0,
#                 5500.0,
#                 5650.0,
#                 5309.0,
#                 5285.0,
#                 5168.0,
#                 4923.0,
#                 4475.0,
#                 4400.0,
#                 4246.0,
#                 3913.0,
#                 3798.0,
#                 3606.0,
#                 3578.0,
#                 3417.0,
#                 2951.0,
#                 2660.0,
#                 2363.0,
#                 2161.0,
#                 1970.0,
#                 1781.0,
#                 1704.0,
#                 1532.0,
#                 1392.0,
#                 1223.0,
#                 1113.0,
#                 1012.0,
#                 997.0,
#                 879.0,
#                 775.0,
#                 725.0,
#                 629.0,
#                 564.0,
#                 479.0,
#                 429.0,
#                 395.0,
#                 419.0,
#                 379.0,
#                 348.0,
#                 383.0,
#                 302.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 701862
#         },
#         {
#             "type": "line",
#             "name": "Ruth",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 26101.0,
#                 25783.0,
#                 23629.0,
#                 23637.0,
#                 23601.0,
#                 22248.0,
#                 20221.0,
#                 19417.0,
#                 17861.0,
#                 16015.0,
#                 14940.0,
#                 13129.0,
#                 12255.0,
#                 11137.0,
#                 10567.0,
#                 9989.0,
#                 9213.0,
#                 9605.0,
#                 9301.0,
#                 9060.0,
#                 8886.0,
#                 8862.0,
#                 9315.0,
#                 9367.0,
#                 8675.0,
#                 8044.0,
#                 8472.0,
#                 8481.0,
#                 7904.0,
#                 7651.0,
#                 7128.0,
#                 7075.0,
#                 6953.0,
#                 6577.0,
#                 6567.0,
#                 6183.0,
#                 6075.0,
#                 5667.0,
#                 5246.0,
#                 5052.0,
#                 4943.0,
#                 4892.0,
#                 4292.0,
#                 3870.0,
#                 3636.0,
#                 3230.0,
#                 2847.0,
#                 2420.0,
#                 2148.0,
#                 1903.0,
#                 1817.0,
#                 1628.0,
#                 1383.0,
#                 1274.0,
#                 1299.0,
#                 1230.0,
#                 1197.0,
#                 1190.0,
#                 1208.0,
#                 1201.0,
#                 1254.0,
#                 1266.0,
#                 1178.0,
#                 1124.0,
#                 1163.0,
#                 1116.0,
#                 1083.0,
#                 1031.0,
#                 998.0,
#                 985.0,
#                 906.0,
#                 985.0,
#                 853.0,
#                 858.0,
#                 880.0,
#                 852.0,
#                 801.0,
#                 856.0,
#                 850.0,
#                 870.0,
#                 903.0,
#                 943.0,
#                 900.0,
#                 888.0,
#                 905.0,
#                 906.0,
#                 889.0,
#                 958.0,
#                 924.0,
#                 912.0,
#                 929.0,
#                 901.0,
#                 926.0,
#                 986.0,

# %% [markdown]
# ## 4. 2000年后越来越流行的名字

# %% [markdown]
# ### - 男

# %%
data_popular_now = data[(data['Year']>=2000)&(data['Gender'] =='M')&(data['Count']>7000)]
data_popular_now = data_popular_now.pivot(index='Name', columns='Year',values='Count')

# %%
year = pd.DataFrame({'Year':list(range(2000, 2018))}, index=list(range(2000, 2018)))

# %%
data_popular_now_corr = data_popular_now.corrwith(year['Year'], axis=1)
boys_names_popular_now = list(data_popular_now_corr[data_popular_now_corr > 0.8].index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
boys_names_popular_now_data = data[(data['Name'].isin(boys_names_popular_now)) & (data['Year']>=1920) & (data['Gender']=='M')]

# %%
boys_names_popular_now_data = boys_names_popular_now_data.pivot(index='Name', columns='Year',values='Count').reset_index().melt('Name', value_name='Count')

# %%
attr = list(range(1920, 2018))
line = Line("",width=800, height=600)
for name in boys_names_popular_now:
    v = list(boys_names_popular_now_data[boys_names_popular_now_data['Name']==name].Count.values)
    line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6fcc244025b64026b344f5d6a843225c" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6fcc244025b64026b344f5d6a843225c = echarts.init(document.getElementById('6fcc244025b64026b344f5d6a843225c'), null, {renderer: 'canvas'});
# var option_6fcc244025b64026b344f5d6a843225c = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7889684,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Carter",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 98.0,
#                 83.0,
#                 93.0,
#                 84.0,
#                 112.0,
#                 88.0,
#                 89.0,
#                 85.0,
#                 78.0,
#                 71.0,
#                 62.0,
#                 78.0,
#                 68.0,
#                 77.0,
#                 97.0,
#                 101.0,
#                 98.0,
#                 99.0,
#                 106.0,
#                 77.0,
#                 88.0,
#                 109.0,
#                 112.0,
#                 130.0,
#                 122.0,
#                 125.0,
#                 148.0,
#                 178.0,
#                 150.0,
#                 178.0,
#                 170.0,
#                 172.0,
#                 156.0,
#                 161.0,
#                 190.0,
#                 150.0,
#                 176.0,
#                 140.0,
#                 164.0,
#                 134.0,
#                 139.0,
#                 132.0,
#                 130.0,
#                 159.0,
#                 133.0,
#                 114.0,
#                 127.0,
#                 141.0,
#                 123.0,
#                 150.0,
#                 156.0,
#                 198.0,
#                 164.0,
#                 131.0,
#                 142.0,
#                 163.0,
#                 158.0,
#                 122.0,
#                 71.0,
#                 65.0,
#                 91.0,
#                 88.0,
#                 118.0,
#                 119.0,
#                 134.0,
#                 176.0,
#                 182.0,
#                 212.0,
#                 265.0,
#                 294.0,
#                 333.0,
#                 391.0,
#                 487.0,
#                 550.0,
#                 543.0,
#                 919.0,
#                 1216.0,
#                 1540.0,
#                 1800.0,
#                 1943.0,
#                 2550.0,
#                 3434.0,
#                 3480.0,
#                 4171.0,
#                 5009.0,
#                 5899.0,
#                 6431.0,
#                 6100.0,
#                 7062.0,
#                 8167.0,
#                 8152.0,
#                 8596.0,
#                 9258.0,
#                 9569.0,
#                 10671.0,
#                 10771.0,
#                 10168.0,
#                 9753.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7889684
#         },
#         {
#             "type": "line",
#             "name": "Elijah",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 277.0,
#                 257.0,
#                 311.0,
#                 302.0,
#                 261.0,
#                 283.0,
#                 276.0,
#                 290.0,
#                 255.0,
#                 243.0,
#                 226.0,
#                 198.0,
#                 233.0,
#                 195.0,
#                 208.0,
#                 211.0,
#                 220.0,
#                 211.0,
#                 195.0,
#                 237.0,
#                 201.0,
#                 238.0,
#                 245.0,
#                 220.0,
#                 228.0,
#                 236.0,
#                 222.0,
#                 296.0,
#                 243.0,
#                 268.0,
#                 282.0,
#                 223.0,
#                 263.0,
#                 248.0,
#                 254.0,
#                 235.0,
#                 196.0,
#                 220.0,
#                 207.0,
#                 185.0,
#                 181.0,
#                 193.0,
#                 178.0,
#                 152.0,
#                 160.0,
#                 123.0,
#                 140.0,
#                 134.0,
#                 122.0,
#                 144.0,
#                 184.0,
#                 195.0,
#                 210.0,
#                 213.0,
#                 288.0,
#                 263.0,
#                 301.0,
#                 503.0,
#                 547.0,
#                 697.0,
#                 754.0,
#                 750.0,
#                 739.0,
#                 670.0,
#                 628.0,
#                 681.0,
#                 718.0,
#                 747.0,
#                 884.0,
#                 991.0,
#                 1138.0,
#                 1345.0,
#                 1518.0,
#                 1880.0,
#                 2620.0,
#                 3978.0,
#                 4815.0,
#                 5086.0,
#                 5662.0,
#                 6595.0,
#                 7470.0,
#                 8336.0,
#                 10050.0,
#                 10658.0,
#                 11707.0,
#                 11605.0,
#                 12044.0,
#                 12405.0,
#                 13225.0,
#                 12825.0,
#                 13891.0,
#                 13960.0,
#                 13865.0,
#                 13783.0,
#                 13813.0,
#                 13628.0,
#                 13867.0,
#                 13268.0
#             ],
#             "label": {
#                 "normal": {

# %% [markdown]
# ### -女

# %%
data_popular_now = data[(data['Year']>=2000)&(data['Gender'] =='F')&(data['Count']>6000)]
data_popular_now = data_popular_now.pivot(index='Name', columns='Year',values='Count')

# %%
data_popular_now_corr = data_popular_now.corrwith(year['Year'], axis=1)
girls_names_popular_now = list(data_popular_now_corr[data_popular_now_corr > 0.7].index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %%
girls_names_popular_now_data = data[(data['Name'].isin(girls_names_popular_now)) & (data['Year']>=1920) & (data['Gender']=='F')]

# %%
girls_names_popular_now_data = girls_names_popular_now_data.pivot(index='Name', columns='Year',values='Count').reset_index().melt('Name', value_name='Count')

# %%
attr = list(range(1920, 2018))
line = Line("",width=800, height=600)
for name in girls_names_popular_now:
    v = list(girls_names_popular_now_data[girls_names_popular_now_data['Name']==name].Count.values)
    line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2fadf879fcaa437a8082a0201136d74b" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2fadf879fcaa437a8082a0201136d74b = echarts.init(document.getElementById('2fadf879fcaa437a8082a0201136d74b'), null, {renderer: 'canvas'});
# var option_2fadf879fcaa437a8082a0201136d74b = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3147172,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Amelia",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 1054.0,
#                 995.0,
#                 1032.0,
#                 965.0,
#                 910.0,
#                 889.0,
#                 746.0,
#                 755.0,
#                 755.0,
#                 687.0,
#                 679.0,
#                 591.0,
#                 637.0,
#                 608.0,
#                 553.0,
#                 604.0,
#                 581.0,
#                 646.0,
#                 570.0,
#                 490.0,
#                 504.0,
#                 529.0,
#                 543.0,
#                 560.0,
#                 475.0,
#                 475.0,
#                 547.0,
#                 538.0,
#                 564.0,
#                 589.0,
#                 483.0,
#                 533.0,
#                 550.0,
#                 550.0,
#                 511.0,
#                 531.0,
#                 525.0,
#                 522.0,
#                 483.0,
#                 501.0,
#                 542.0,
#                 571.0,
#                 493.0,
#                 503.0,
#                 503.0,
#                 475.0,
#                 430.0,
#                 450.0,
#                 390.0,
#                 465.0,
#                 493.0,
#                 482.0,
#                 405.0,
#                 442.0,
#                 506.0,
#                 524.0,
#                 523.0,
#                 601.0,
#                 643.0,
#                 702.0,
#                 768.0,
#                 849.0,
#                 833.0,
#                 759.0,
#                 1094.0,
#                 1014.0,
#                 1018.0,
#                 1006.0,
#                 1128.0,
#                 1265.0,
#                 1511.0,
#                 1536.0,
#                 1344.0,
#                 1248.0,
#                 1253.0,
#                 1206.0,
#                 1289.0,
#                 1316.0,
#                 1424.0,
#                 1419.0,
#                 1531.0,
#                 1634.0,
#                 2441.0,
#                 3093.0,
#                 3350.0,
#                 3907.0,
#                 4061.0,
#                 4193.0,
#                 4346.0,
#                 4695.0,
#                 5455.0,
#                 6368.0,
#                 7242.0,
#                 8032.0,
#                 8789.0,
#                 9852.0,
#                 10753.0,
#                 11800.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3147172
#         },
#         {
#             "type": "line",
#             "name": "Aria",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 NaN,
#                 5.0,
#                 8.0,
#                 5.0,
#                 NaN,
#                 10.0,
#                 NaN,
#                 7.0,
#                 6.0,
#                 6.0,
#                 5.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 6.0,
#                 7.0,
#                 9.0,
#                 NaN,
#                 NaN,
#                 5.0,
#                 6.0,
#                 5.0,
#                 NaN,
#                 NaN,
#                 7.0,
#                 5.0,
#                 5.0,
#                 5.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 5.0,
#                 NaN,
#                 6.0,
#                 NaN,
#                 6.0,
#                 5.0,
#                 8.0,
#                 14.0,
#                 9.0,
#                 19.0,
#                 18.0,
#                 13.0,
#                 13.0,
#                 18.0,
#                 28.0,
#                 19.0,
#                 28.0,
#                 33.0,
#                 30.0,
#                 50.0,
#                 49.0,
#                 55.0,
#                 46.0,
#                 41.0,
#                 56.0,
#                 77.0,
#                 77.0,
#                 91.0,
#                 91.0,
#                 102.0,
#                 74.0,
#                 105.0,
#                 151.0,
#                 143.0,
#                 133.0,
#                 178.0,
#                 202.0,
#                 221.0,
#                 321.0,
#                 331.0,
#                 402.0,
#                 402.0,
#                 384.0,
#                 444.0,
#                 530.0,
#                 540.0,
#                 592.0,
#                 903.0,
#                 1980.0,
#                 3228.0,
#                 5111.0,
#                 5918.0,
#                 6403.0,
#                 6927.0,
#                 7132.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "co

# %% [markdown]
# ## 5. 影响美国人取名的因素：体育明星、电视明星

# %%
from pyecharts import Overlap
def name_trend(name, data, gender=['M','F'], year=1920, dodge = 500):
    if isinstance(gender, str):
        name_data = data[(data['Name'] == name)&(data['Gender']==gender)&(data['Year']>=year)]
        attr = list(name_data['Year'].values)
        bar = Bar(name)
        bar.add("", attr, list(name_data['Count'].values), mark_line=["average"], mark_point=["max", "min"],
               legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
        line = Line()
        line.add("", attr, list(name_data['Count'].values + dodge))
        
    else:
        name_data = data[(data['Name'] == name)&(data['Year']>=year)]
        attr = list(range(year, 2018))
        v1 = name_data[name_data['Gender']==gender[0]].Count.values
        v2 = name_data[name_data['Gender']==gender[1]].Count.values
        bar = Bar(name)
        bar.add("男", attr, list(v1), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
        bar.add("女", attr, list(v2), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
        line = Line()
        line.add("", attr, list(v1 + dodge))
        line.add("", attr, list(v2 + dodge))
    
    overlap = Overlap()
    overlap.add(bar)
    overlap.add(line)
    return overlap

# %% [markdown]
# - 体育明星：Jordan, Kobe, Lebron

# %%
name_trend('Jordan',data,gender='M',year=1960)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="21a5be45ba3a4e3a92794229491c07b1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_21a5be45ba3a4e3a92794229491c07b1 = echarts.init(document.getElementById('21a5be45ba3a4e3a92794229491c07b1'), null, {renderer: 'canvas'});
# var option_21a5be45ba3a4e3a92794229491c07b1 = {
#     "title": [
#         {
#             "text": "Jordan",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3348323,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 137.0,
#                 187.0,
#                 182.0,
#                 154.0,
#                 165.0,
#                 179.0,
#                 212.0,
#                 221.0,
#                 189.0,
#                 223.0,
#                 279.0,
#                 290.0,
#                 258.0,
#                 305.0,
#                 369.0,
#                 397.0,
#                 517.0,
#                 649.0,
#                 981.0,
#                 1406.0,
#                 1619.0,
#                 2922.0,
#                 3535.0,
#                 4013.0,
#                 4539.0,
#                 5456.0,
#                 7300.0,
#                 8408.0,
#                 8485.0,
#                 10871.0,
#                 16133.0,
#                 16013.0,
#                 14029.0,
#                 14753.0,
#                 14160.0,
#                 13567.0,
#                 13852.0,
#                 14759.0,
#                 14409.0,
#                 13051.0,
#                 12167.0,
#                 10813.0,
#                 11147.0,
#                 10328.0,
#                 9554.0,
#                 9394.0,
#                 9923.0,
#                 10046.0,
#                 9086.0,
#                 8651.0,
#                 8230.0,
#                 8065.0,
#                 7802.0,
#                 7189.0,
#                 6860.0,
#                 6287.0,
#                 5618.0,
#                 5114.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3348323
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 637.0,
#                 687.0,
#                 682.0,
#                 654.0,
#                 665.0,
#                 679.0,
#                 712.0,
#                 721.0,
#                 689.0,
#                 723.0,
#                 779.0,
#                 790.0,
#                 758.0,
#                 805.0,
#                 869.0,
#                 897.0,
#                 1017.0,
#                 1149.0,
#                 1481.0,
#                 1906.0,
#                 2119.0,
#                 3422.0,
#                 4035.0,
#                 4513.0,
#                 5039.0,
#                 5956.0,
#                 7800.0,
#                 8908.0,
#                 8985.0,
#                 11371.0,
#                 16633.0,
#                 16513.0,
#                 14529.0,
#                 15253.0,
#                 14660.0,
#                 14067.0,
#                 14352.0,
#                 15259.0,
#                 14909.0,
#                 13551.0,
#                 12667.0,
#                 11313.0,
#                 11647.0,
#                 10828.0,
#                 10054.0,
#                 9894.0,
#                 10423.0,
#                 10546.0,
#                 9586.0,
#                 9151.0,
#                 8730.0,
#                 8565.0,
#                 8302.0,
#                 7689.0,
#                 7360.0,
#                 6787.0,
#                 6118.0,
#                 5614.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine"

# %%
name_trend('Kobe',data,gender='M',year=1920, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="328a49f514b344c59e3160c07375a328" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_328a49f514b344c59e3160c07375a328 = echarts.init(document.getElementById('328a49f514b344c59e3160c07375a328'), null, {renderer: 'canvas'});
# var option_328a49f514b344c59e3160c07375a328 = {
#     "title": [
#         {
#             "text": "Kobe",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5474547,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 5.0,
#                 9.0,
#                 87.0,
#                 350.0,
#                 1104.0,
#                 860.0,
#                 1432.0,
#                 1552.0,
#                 1392.0,
#                 1212.0,
#                 625.0,
#                 443.0,
#                 469.0,
#                 572.0,
#                 730.0,
#                 685.0,
#                 644.0,
#                 553.0,
#                 525.0,
#                 551.0,
#                 519.0,
#                 465.0,
#                 583.0,
#                 527.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5474547
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 105.0,
#                 109.0,
#                 187.0,
#                 450.0,
#                 1204.0,
#                 960.0,
#                 1532.0,
#                 1652.0,
#                 1492.0,
#                 1312.0,
#                 725.0,
#                 543.0,
#                 569.0,
#                 672.0,
#                 830.0,
#                 785.0,
#                 744.0,
#                 653.0,
#                 625.0,
#                 651.0,
#                 619.0,
#                 565.0,
#                 683.0,
#                 627.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5474547,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 1989.0,
#                 1995.0,
#                 1996.0,
#                 1997.0,
#                 1998.0,
#                 1999.0,
#                 2000.0,
#                 2001.0,
#                 2002.0,
#                 2003.0,
#                 2004.0,
#                 2005.0,
#                 2006.0,
#                 2007.0,
#                 2008.0,
#                 2009.0,

# %% [markdown]
# - 影视明星：Emma, Scarlett

# %%
name_trend('Emma',data,gender='F',year=1980)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e179ab3e2a2e47718c89e8fb48311ae7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e179ab3e2a2e47718c89e8fb48311ae7 = echarts.init(document.getElementById('e179ab3e2a2e47718c89e8fb48311ae7'), null, {renderer: 'canvas'});
# var option_e179ab3e2a2e47718c89e8fb48311ae7 = {
#     "title": [
#         {
#             "text": "Emma",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3558475,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 533.0,
#                 534.0,
#                 562.0,
#                 551.0,
#                 676.0,
#                 944.0,
#                 1257.0,
#                 1588.0,
#                 1788.0,
#                 1935.0,
#                 2417.0,
#                 2592.0,
#                 3209.0,
#                 4104.0,
#                 4763.0,
#                 5044.0,
#                 6143.0,
#                 7739.0,
#                 10437.0,
#                 11728.0,
#                 12548.0,
#                 13307.0,
#                 16538.0,
#                 22704.0,
#                 21606.0,
#                 20339.0,
#                 19114.0,
#                 18372.0,
#                 18809.0,
#                 17892.0,
#                 17338.0,
#                 18797.0,
#                 20934.0,
#                 20936.0,
#                 20924.0,
#                 20435.0,
#                 19471.0,
#                 19738.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3558475
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 1033.0,
#                 1034.0,
#                 1062.0,
#                 1051.0,
#                 1176.0,
#                 1444.0,
#                 1757.0,
#                 2088.0,
#                 2288.0,
#                 2435.0,
#                 2917.0,
#                 3092.0,
#                 3709.0,
#                 4604.0,
#                 5263.0,
#                 5544.0,
#                 6643.0,
#                 8239.0,
#                 10937.0,
#                 12228.0,
#                 13048.0,
#                 13807.0,
#                 17038.0,
#                 23204.0,
#                 22106.0,
#                 20839.0,
#                 19614.0,
#                 18872.0,
#                 19309.0,
#                 18392.0,
#                 17838.0,
#                 19297.0,
#                 21434.0,
#                 21436.0,
#                 21424.0,
#                 20935.0,
#                 19971.0,
#                 20238.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3558475,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textSt

# %%
name_trend('Scarlett',data,gender='F',year=1980, dodge=200)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="578e210a0f534ce3b5d262d33f520c38" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_578e210a0f534ce3b5d262d33f520c38 = echarts.init(document.getElementById('578e210a0f534ce3b5d262d33f520c38'), null, {renderer: 'canvas'});
# var option_578e210a0f534ce3b5d262d33f520c38 = {
#     "title": [
#         {
#             "text": "Scarlett",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6038135,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 121.0,
#                 113.0,
#                 87.0,
#                 92.0,
#                 124.0,
#                 112.0,
#                 137.0,
#                 151.0,
#                 131.0,
#                 138.0,
#                 167.0,
#                 151.0,
#                 204.0,
#                 250.0,
#                 235.0,
#                 272.0,
#                 248.0,
#                 230.0,
#                 254.0,
#                 245.0,
#                 227.0,
#                 237.0,
#                 290.0,
#                 326.0,
#                 538.0,
#                 733.0,
#                 1116.0,
#                 1582.0,
#                 1620.0,
#                 1920.0,
#                 2716.0,
#                 3558.0,
#                 4042.0,
#                 5050.0,
#                 6003.0,
#                 7125.0,
#                 7698.0,
#                 7679.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "valueDim": null,
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "valueDim": null
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6038135
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 321.0,
#                 313.0,
#                 287.0,
#                 292.0,
#                 324.0,
#                 312.0,
#                 337.0,
#                 351.0,
#                 331.0,
#                 338.0,
#                 367.0,
#                 351.0,
#                 404.0,
#                 450.0,
#                 435.0,
#                 472.0,
#                 448.0,
#                 430.0,
#                 454.0,
#                 445.0,
#                 427.0,
#                 437.0,
#                 490.0,
#                 526.0,
#                 738.0,
#                 933.0,
#                 1316.0,
#                 1782.0,
#                 1820.0,
#                 2120.0,
#                 2916.0,
#                 3758.0,
#                 4242.0,
#                 5250.0,
#                 6203.0,
#                 7325.0,
#                 7898.0,
#                 7879.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6038135,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"

# %%
name_trend('Chandler',data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7714251248d4432bb882f68f1981ef4b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7714251248d4432bb882f68f1981ef4b = echarts.init(document.getElementById('7714251248d4432bb882f68f1981ef4b'), null, {renderer: 'canvas'});
# var option_7714251248d4432bb882f68f1981ef4b = {
#     "title": [
#         {
#             "text": "Chandler",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1949925,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 66.0,
#                 48.0,
#                 63.0,
#                 70.0,
#                 66.0,
#                 70.0,
#                 90.0,
#                 88.0,
#                 118.0,
#                 120.0,
#                 142.0,
#                 198.0,
#                 224.0,
#                 301.0,
#                 396.0,
#                 467.0,
#                 553.0,
#                 661.0,
#                 704.0,
#                 1856.0,
#                 2185.0,
#                 1796.0,
#                 1952.0,
#                 2395.0,
#                 2131.0,
#                 1792.0,
#                 1417.0,
#                 1270.0,
#                 1130.0,
#                 870.0,
#                 753.0,
#                 674.0,
#                 607.0,
#                 579.0,
#                 524.0,
#                 615.0,
#                 595.0,
#                 674.0,
#                 730.0,
#                 730.0,
#                 652.0,
#                 590.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1949925
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 7.0,
#                 7.0,
#                 5.0,
#                 7.0,
#                 19.0,
#                 18.0,
#                 18.0,
#                 21.0,
#                 18.0,
#                 14.0,
#                 20.0,
#                 36.0,
#                 41.0,
#                 65.0,
#                 84.0,
#                 90.0,
#                 437.0,
#                 733.0,
#                 570.0,
#                 744.0,
#                 493.0,
#                 416.0,
#                 412.0,
#                 447.0,
#                 326.0,
#                 240.0,
#                 223.0,
#                 172.0,
#                 136.0,
#                 156.0,
#                 132.0,
#                 135.0,
#                 122.0,
#                 100.0,
#                 116.0,
#                 140.0,
#                 161.0,
#                 195.0,
#                 222.0,
#                 249.0,
#                 264.0,
#                 246.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1949925
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 166.0,
#                 148.0,
#                 163.0,
#                 170.0,
#                 166.0,
#                 170.0,
#                 190.0,
#                 188.0,
#                 218.0,
#                 220.0,
#                 242.0,
#                 298.0,
#                 324.0,
#                 401.0,
#                 496.0,
#                 567.0,
#                 653.0,
#                 761.0,
#                 804.0,
#                 1956.0,
#                 2285.0,
#                 1896.0,
#                 2052.0,
#                 2495.0,
#                 2231.0,
#                 1892.0,
#                 1517.0,
#                 1370.0,
#                 1230.0,
#                 970.0,
#                 853.0,
#                 774.0,
#                 707.0,
#                 679.0,
#                 624.0,
#                 715.0,
#                 695.0,
#                 774.0,
#                 830.0,
#                 830.0,
#                 752.0,
#                 690.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1949925,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "line",
#             "name": "",

# %%
name_trend('Taylor',data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c2f54b81b455424d851c83ebcdc3bbf2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c2f54b81b455424d851c83ebcdc3bbf2 = echarts.init(document.getElementById('c2f54b81b455424d851c83ebcdc3bbf2'), null, {renderer: 'canvas'});
# var option_c2f54b81b455424d851c83ebcdc3bbf2 = {
#     "title": [
#         {
#             "text": "Taylor",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3964968,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 240.0,
#                 319.0,
#                 344.0,
#                 448.0,
#                 617.0,
#                 775.0,
#                 947.0,
#                 1055.0,
#                 1415.0,
#                 1794.0,
#                 2035.0,
#                 2431.0,
#                 3488.0,
#                 4856.0,
#                 6576.0,
#                 7967.0,
#                 8240.0,
#                 7688.0,
#                 6624.0,
#                 5519.0,
#                 4796.0,
#                 4332.0,
#                 3581.0,
#                 3071.0,
#                 2853.0,
#                 2309.0,
#                 1964.0,
#                 1828.0,
#                 1613.0,
#                 1576.0,
#                 1629.0,
#                 1430.0,
#                 1365.0,
#                 1093.0,
#                 955.0,
#                 899.0,
#                 886.0,
#                 824.0,
#                 695.0,
#                 656.0,
#                 641.0,
#                 571.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3964968
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 68.0,
#                 123.0,
#                 120.0,
#                 148.0,
#                 234.0,
#                 387.0,
#                 606.0,
#                 684.0,
#                 869.0,
#                 1050.0,
#                 1214.0,
#                 1706.0,
#                 2796.0,
#                 4069.0,
#                 7257.0,
#                 10253.0,
#                 14949.0,
#                 21266.0,
#                 20733.0,
#                 20425.0,
#                 19151.0,
#                 19503.0,
#                 18572.0,
#                 16905.0,
#                 15078.0,
#                 13690.0,
#                 11467.0,
#                 10308.0,
#                 9303.0,
#                 8671.0,
#                 8557.0,
#                 7960.0,
#                 8335.0,
#                 7582.0,
#                 5894.0,
#                 5188.0,
#                 4864.0,
#                 4135.0,
#                 3808.0,
#                 3744.0,
#                 3271.0,
#                 2692.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3964968
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 340.0,
#                 419.0,
#                 444.0,
#                 548.0,
#                 717.0,
#                 875.0,
#                 1047.0,
#                 1155.0,
#                 1515.0,
#                 1894.0,
#                 2135.0,
#                 2531.0,
#                 3588.0,
#                 4956.0,
#                 6676.0,
#                 8067.0,
#                 8340.0,
#                 7788.0,
#                 6724.0,
#                 5619.0,
#                 4896.0,
#                 4432.0,
#                 3681.0,
#                 3171.0,
#                 2953.0,
#                 2409.0,
#                 2064.0,
#                 1928.0,
#                 1713.0,
#                 1676.0,
#                 1729.0,
#                 1530.0,
#                 1465.0,
#                 1193.0,
#                 1055.0,
#                 999.0,
#                 986.0,
#                 924.0,
#                 795.0,
#                 756.0,
#                 741.0,
#                 671.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3964968,
#             "xAxisIndex": 0,

# %%
name_trend('Riley', data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1e7c25c995124193bb33a8552285f87c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1e7c25c995124193bb33a8552285f87c = echarts.init(document.getElementById('1e7c25c995124193bb33a8552285f87c'), null, {renderer: 'canvas'});
# var option_1e7c25c995124193bb33a8552285f87c = {
#     "title": [
#         {
#             "text": "Riley",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 172973,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 106.0,
#                 117.0,
#                 167.0,
#                 162.0,
#                 164.0,
#                 181.0,
#                 199.0,
#                 225.0,
#                 253.0,
#                 333.0,
#                 403.0,
#                 476.0,
#                 528.0,
#                 676.0,
#                 813.0,
#                 865.0,
#                 1067.0,
#                 1376.0,
#                 1587.0,
#                 1918.0,
#                 2393.0,
#                 2833.0,
#                 3013.0,
#                 2970.0,
#                 3420.0,
#                 3651.0,
#                 3959.0,
#                 4076.0,
#                 4109.0,
#                 4110.0,
#                 4392.0,
#                 3969.0,
#                 4129.0,
#                 3785.0,
#                 3642.0,
#                 3457.0,
#                 2877.0,
#                 2552.0,
#                 2441.0,
#                 2086.0,
#                 1714.0,
#                 1454.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 172973
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 7.0,
#                 11.0,
#                 13.0,
#                 15.0,
#                 18.0,
#                 24.0,
#                 36.0,
#                 37.0,
#                 22.0,
#                 64.0,
#                 99.0,
#                 88.0,
#                 123.0,
#                 168.0,
#                 238.0,
#                 285.0,
#                 425.0,
#                 552.0,
#                 755.0,
#                 969.0,
#                 1148.0,
#                 1669.0,
#                 1877.0,
#                 2312.0,
#                 2552.0,
#                 3044.0,
#                 3905.0,
#                 4242.0,
#                 4982.0,
#                 5124.0,
#                 5055.0,
#                 5208.0,
#                 5768.0,
#                 5633.0,
#                 5537.0,
#                 5031.0,
#                 4825.0,
#                 4931.0,
#                 4790.0,
#                 5726.0,
#                 7131.0,
#                 6343.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 172973
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 206.0,
#                 217.0,
#                 267.0,
#                 262.0,
#                 264.0,
#                 281.0,
#                 299.0,
#                 325.0,
#                 353.0,
#                 433.0,
#                 503.0,
#                 576.0,
#                 628.0,
#                 776.0,
#                 913.0,
#                 965.0,
#                 1167.0,
#                 1476.0,
#                 1687.0,
#                 2018.0,
#                 2493.0,
#                 2933.0,
#                 3113.0,
#                 3070.0,
#                 3520.0,
#                 3751.0,
#                 4059.0,
#                 4176.0,
#                 4209.0,
#                 4210.0,
#                 4492.0,
#                 4069.0,
#                 4229.0,
#                 3885.0,
#                 3742.0,
#                 3557.0,
#                 2977.0,
#                 2652.0,
#                 2541.0,
#                 2186.0,
#                 1814.0,
#                 1554.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 172973,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {

# %% [markdown]
# ## 6. 为什么同一发音的名字，有很多不同的拼写变体？
# - Catherine/Katharine
# [C|k]ath(.*)

# %%
Catherine = data['Name'][data['Name'].str.contains('^[C|K]ath(.*)')].unique()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
Catherine_data = data[data['Name'].isin(Catherine)].groupby('Name').Count.sum()

# %%
name = list(Catherine_data.index)
value = list(Catherine_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed
wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="dc20ce70d22041c18915d244df487c81" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_dc20ce70d22041c18915d244df487c81 = echarts.init(document.getElementById('dc20ce70d22041c18915d244df487c81'), null, {renderer: 'canvas'});
# var option_dc20ce70d22041c18915d244df487c81 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1113652,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Cath",
#                     "value": 11.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,38,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catha",
#                     "value": 149.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,28,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathal",
#                     "value": 40.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,76,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathaleen",
#                     "value": 323.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,140,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathalene",
#                     "value": 21.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,33,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathaleya",
#                     "value": 34.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,132,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathalia",
#                     "value": 5.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(91,122,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathalina",
#                     "value": 108.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,9,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathaline",
#                     "value": 10.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,43,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathan",
#                     "value": 97.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,26,80)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catharina",
#                     "value": 283.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,9,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catharine",
#                     "value": 12936.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,103,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathay",
#                     "value": 30.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,6,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathe",
#                     "value": 255.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,27,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathee",
#                     "value": 27.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,154,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catheleen",
#                     "value": 61.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,155,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cathelene",
#                     "value": 47.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,78,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catheline",
#                     "value": 92.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,149,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Cather",
#                     "value": 27.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,48,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catheren",
#                     "value": 10.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,158,109)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Catherene",
#                     "value": 256.0,
#                     "textStyle": {
#                         "normal": {
#                             "

# %%
Emily = data['Name'][data['Name'].str.contains('Emil(.*)')].unique()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
Emily_data = data[data['Name'].isin(Emily)].groupby('Name').Count.sum()

# %%
name = list(Emily_data.index)
value = list(Emily_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed
wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="07247396b17f47aa99146978167c78bf" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_07247396b17f47aa99146978167c78bf = echarts.init(document.getElementById('07247396b17f47aa99146978167c78bf'), null, {renderer: 'canvas'});
# var option_07247396b17f47aa99146978167c78bf = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5623602,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Emil",
#                     "value": 31942.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,49,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emila",
#                     "value": 84.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(48,155,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilce",
#                     "value": 59.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,156,66)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilda",
#                     "value": 22.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,58,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emile",
#                     "value": 8712.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,107,76)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilea",
#                     "value": 425.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,117,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emileah",
#                     "value": 55.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,37,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilee",
#                     "value": 22428.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,125,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emileigh",
#                     "value": 1236.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,74,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilene",
#                     "value": 96.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,8,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emileo",
#                     "value": 93.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,47,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emiley",
#                     "value": 1717.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,131,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emili",
#                     "value": 1771.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,122,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilia",
#                     "value": 31873.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,50,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emiliah",
#                     "value": 37.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,159,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilian",
#                     "value": 90.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,31,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emiliana",
#                     "value": 1574.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,74,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emiliann",
#                     "value": 5.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,58,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilianna",
#                     "value": 124.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,100,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emilianne",
#                     "value": 10.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,97,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Emiliano",
#                     "value": 21923.0,
#                     "textStyle": {
#                         "normal": {
#                             "color

# %% [markdown]
# ## 7. 一些具有特殊含义的名字，有多少人取？

# %%
def name_trend2(name, data, gender, dodge=100):
    name_data = data[(data['Name']==name)&(data['Gender']==gender)]
    attr = list(name_data['Year'].values)
    v1 = name_data['Count'].values

    bar = Bar(name)
    bar.add("", attr, list(v1), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
    
    line = Line()
    line.add("", attr, list(v1 + dodge))
    
    overlap = Overlap()
    overlap.add(bar)
    overlap.add(line)
    return overlap

# %%
name_trend2('Dick',data,gender='M', dodge=50)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5de11e3e6e004d5fb5405f0be5d03346" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5de11e3e6e004d5fb5405f0be5d03346 = echarts.init(document.getElementById('5de11e3e6e004d5fb5405f0be5d03346'), null, {renderer: 'canvas'});
# var option_5de11e3e6e004d5fb5405f0be5d03346 = {
#     "title": [
#         {
#             "text": "Dick",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 1204775,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 25.0,
#                 20.0,
#                 14.0,
#                 24.0,
#                 37.0,
#                 27.0,
#                 23.0,
#                 27.0,
#                 27.0,
#                 22.0,
#                 31.0,
#                 18.0,
#                 24.0,
#                 20.0,
#                 25.0,
#                 22.0,
#                 27.0,
#                 23.0,
#                 29.0,
#                 30.0,
#                 45.0,
#                 21.0,
#                 35.0,
#                 18.0,
#                 24.0,
#                 36.0,
#                 32.0,
#                 38.0,
#                 34.0,
#                 46.0,
#                 52.0,
#                 37.0,
#                 77.0,
#                 94.0,
#                 129.0,
#                 167.0,
#                 221.0,
#                 220.0,
#                 251.0,
#                 269.0,
#                 329.0,
#                 349.0,
#                 363.0,
#                 350.0,
#                 442.0,
#                 563.0,
#                 650.0,
#                 775.0,
#                 834.0,
#                 841.0,
#                 940.0,
#                 992.0,
#                 1053.0,
#                 1045.0,
#                 1131.0,
#                 1093.0,
#                 1088.0,
#                 1008.0,
#                 935.0,
#                 876.0,
#                 911.0,
#                 894.0,
#                 860.0,
#                 856.0,
#                 808.0,
#                 758.0,
#                 828.0,
#                 755.0,
#                 552.0,
#                 340.0,
#                 269.0,
#                 246.0,
#                 215.0,
#                 215.0,
#                 166.0,
#                 182.0,
#                 192.0,
#                 201.0,
#                 234.0,
#                 219.0,
#                 186.0,
#                 184.0,
#                 147.0,
#                 128.0,
#                 110.0,
#                 100.0,
#                 65.0,
#                 74.0,
#                 62.0,
#                 57.0,
#                 52.0,
#                 38.0,
#                 29.0,
#                 35.0,
#                 33.0,
#                 23.0,
#                 20.0,
#                 19.0,
#                 21.0,
#                 17.0,
#                 20.0,
#                 9.0,
#                 17.0,
#                 19.0,
#                 11.0,
#                 13.0,
#                 10.0,
#                 12.0,
#                 10.0,
#                 10.0,
#                 5.0,
#                 6.0,
#                 6.0,
#                 6.0,
#                 6.0,
#                 6.0,
#                 5.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1204775
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 75.0,
#                 70.0,
#                 64.0,
#                 74.0,
#                 87.0,
#                 77.0,
#                 73.0,
#                 77.0,
#                 77.0,
#                 72.0,
#                 81.0,
#                 68.0,
#                 74.0,
#                 70.0,
#                 75.0,
#                 72.0,
#                 77.0,
#                 73.0,
#                 79.0,
#                 80.0,
#                 95.0,
#                 71.0,
#                 85.0,
#                 68.0,
#                 74.0,
#                 86.0,
#                 82.0,
#                 88.0,
#                 84.0,
#                 96.0,
#                 102.0,
#                 87.0,
#                 127.0,
#                 144.0,
#                 179.0,
#                 217.0,
#                 271.0,
#                 270.0,
#                 301.0,
#                 319.0,
#                 379.0,
#                 399.0,
#                 413.0,
#                 400.0,
#                 492.0,
#                 613.0,
#                 700.0,
#                 825.0,
#                 884.0,
#                 891.0,
#                 990.0,
#                 1042.0,
#                 1103.0,
#                 1095.0,
#                 1181.0,
#                 1143.0,
#                 1138.0,
#                 1058.0,
#                 985.0,
#                 926.0,
#                 961.0,
#                 944.0,
#                 910.0,
#                 906.0,
#                 858.0,
#                 808.0,
#                 878.0,
#                 805.0,
#                 602.0,
#                 390.0,
#                 319.0,
#                 296.0,
#                 265.0,
#                 265.0,
#                 216.0,
#                 232.0,
#                 242.0,
#                 251.0,
#                 284.0,
#                 269.0,
#                 236.0,
#                 234.0,
#                 197.0,
#                 178.0,
#                 160.0,
#                 150.0,
#                 115.0,
#                 124.0,
#                 112.0,
#                 107.0,
#                 102.0,
#                 88.0,
#                 79.0,
#                 85.0,
#                 83.0,
#                 73.0,
#                 70.0,
#                 69.0,
#                 71.0,
#                 67.0,
#                 70.0,
#                 59.0,
#                 67.0,
#                 69.0,
#                 61.0,
#                 63.0,
#                 60.0,
#                 62.0,
#                 60.0,
#                 60.0,

# %%
name_trend2('Dong', data, gender='M', dodge=1)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5c1d5cbad82c40dda213620b03abf919" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5c1d5cbad82c40dda213620b03abf919 = echarts.init(document.getElementById('5c1d5cbad82c40dda213620b03abf919'), null, {renderer: 'canvas'});
# var option_5c1d5cbad82c40dda213620b03abf919 = {
#     "title": [
#         {
#             "text": "Dong",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 289431,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 5.0,
#                 5.0,
#                 5.0,
#                 6.0,
#                 6.0,
#                 5.0,
#                 5.0,
#                 7.0,
#                 7.0,
#                 5.0,
#                 10.0,
#                 10.0,
#                 12.0,
#                 17.0,
#                 9.0,
#                 8.0,
#                 13.0,
#                 6.0,
#                 11.0,
#                 7.0,
#                 13.0,
#                 12.0,
#                 19.0,
#                 13.0,
#                 16.0,
#                 12.0,
#                 11.0,
#                 8.0,
#                 5.0,
#                 5.0,
#                 5.0,
#                 8.0,
#                 9.0,
#                 5.0,
#                 7.0,
#                 5.0,
#                 6.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 289431
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 6.0,
#                 6.0,
#                 6.0,
#                 7.0,
#                 7.0,
#                 6.0,
#                 6.0,
#                 8.0,
#                 8.0,
#                 6.0,
#                 11.0,
#                 11.0,
#                 13.0,
#                 18.0,
#                 10.0,
#                 9.0,
#                 14.0,
#                 7.0,
#                 12.0,
#                 8.0,
#                 14.0,
#                 13.0,
#                 20.0,
#                 14.0,
#                 17.0,
#                 13.0,
#                 12.0,
#                 9.0,
#                 6.0,
#                 6.0,
#                 6.0,
#                 9.0,
#                 10.0,
#                 6.0,
#                 8.0,
#                 6.0,
#                 7.0
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": null
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0,
#                 "color": null
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 289431,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 18,
#                 "color": "#333"
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "xAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 18,
#                     "color": "#000"
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "position": null,
#             "boundaryGap": true,
#             "min": null,
#             "max": null,
#             "data": [
#                 1956.0,
#                 1964.0,
#                 1965.0,
#                 1967.0,
#                 1968.0,
#                 1969.0,
#                 1970.0,
#                 1972.0,
#                 1976.0,
#                 1977.0,
#                 1979.0,
#                 1980.0,
#                 1981.0,
#                 1982.0,
#                 1983.0,
#                 1984.0,
#                 1985.0,
#                 1986.0,
#                 1987.0,
#                 1988.0,
#                 1989.0,
#                 1990.0,
#                 1991.0,
#                 1992.0,
#                 1993.0,
#                 1994.0,
#                 1995.0,
#                 1996.0,
#                 1997.0,
#                 1998.0,
#                 1999.0,
#                 2000.0,
#                 2001.0,
#                 2002.0,
#                 2003.0,
#                 2012.0,
#                 2017.0
#             ],
#             "type": "category"
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "",
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisLabel": {

# %%
name_trend2('Cherry',data,gender='F', dodge=10)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3a3db8e76b17422e8deca84f83e1b7e3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3a3db8e76b17422e8deca84f83e1b7e3 = echarts.init(document.getElementById('3a3db8e76b17422e8deca84f83e1b7e3'), null, {renderer: 'canvas'});
# var option_3a3db8e76b17422e8deca84f83e1b7e3 = {
#     "title": [
#         {
#             "text": "Cherry",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5049837,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "",
#             "data": [
#                 6.0,
#                 5.0,
#                 7.0,
#                 5.0,
#                 7.0,
#                 10.0,
#                 7.0,
#                 5.0,
#                 10.0,
#                 8.0,
#                 10.0,
#                 13.0,
#                 10.0,
#                 8.0,
#                 15.0,
#                 10.0,
#                 13.0,
#                 11.0,
#                 13.0,
#                 8.0,
#                 13.0,
#                 8.0,
#                 15.0,
#                 6.0,
#                 10.0,
#                 12.0,
#                 11.0,
#                 11.0,
#                 18.0,
#                 13.0,
#                 20.0,
#                 12.0,
#                 26.0,
#                 38.0,
#                 25.0,
#                 33.0,
#                 44.0,
#                 34.0,
#                 34.0,
#                 54.0,
#                 42.0,
#                 43.0,
#                 62.0,
#                 75.0,
#                 52.0,
#                 58.0,
#                 68.0,
#                 77.0,
#                 80.0,
#                 74.0,
#                 102.0,
#                 78.0,
#                 94.0,
#                 92.0,
#                 63.0,
#                 81.0,
#                 90.0,
#                 87.0,
#                 112.0,
#                 93.0,
#                 144.0,
#                 146.0,
#                 197.0,
#                 219.0,
#                 318.0,
#                 354.0,
#                 343.0,
#                 292.0,
#                 246.0,
#                 268.0,
#                 300.0,
#                 265.0,
#                 261.0,
#                 251.0,
#                 302.0,
#                 299.0,
#                 232.0,
#                 216.0,
#                 222.0,
#                 185.0,
#                 163.0,
#                 161.0,
#                 175.0,
#                 140.0,
#                 112.0,
#                 174.0,
#                 145.0,
#                 150.0,
#                 157.0,
#                 155.0,
#                 143.0,
#                 139.0,
#                 124.0,
#                 117.0,
#                 106.0,
#                 128.0,
#                 103.0,
#                 103.0,
#                 108.0,
#                 82.0,
#                 89.0,
#                 67.0,
#                 83.0,
#                 67.0,
#                 72.0,
#                 59.0,
#                 58.0,
#                 45.0,
#                 53.0,
#                 60.0,
#                 54.0,
#                 42.0,
#                 34.0,
#                 30.0,
#                 31.0,
#                 29.0,
#                 32.0,
#                 22.0,
#                 31.0,
#                 21.0,
#                 15.0,
#                 19.0,
#                 22.0,
#                 29.0,
#                 31.0,
#                 38.0,
#                 32.0,
#                 24.0,
#                 21.0,
#                 26.0,
#                 39.0,
#                 35.0,
#                 46.0,
#                 43.0,
#                 40.0,
#                 26.0
#             ],
#             "stack": "",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5049837
#         },
#         {
#             "type": "line",
#             "name": "",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "stack": "",
#             "showSymbol": true,
#             "data": [
#                 16.0,
#                 15.0,
#                 17.0,
#                 15.0,
#                 17.0,
#                 20.0,
#                 17.0,
#                 15.0,
#                 20.0,
#                 18.0,
#                 20.0,
#                 23.0,
#                 20.0,
#                 18.0,
#                 25.0,
#                 20.0,
#                 23.0,
#                 21.0,
#                 23.0,
#                 18.0,
#                 23.0,
#                 18.0,
#                 25.0,
#                 16.0,
#                 20.0,
#                 22.0,
#                 21.0,
#                 21.0,
#                 28.0,
#                 23.0,
#                 30.0,
#                 22.0,
#                 36.0,
#                 48.0,
#                 35.0,
#                 43.0,
#                 54.0,
#                 44.0,
#                 44.0,
#                 64.0,
#                 52.0,
#                 53.0,
#                 72.0,
#                 85.0,
#                 62.0,
#                 68.0,
#                 78.0,
#                 87.0,
#                 90.0,
#                 84.0,
#                 112.0,
#                 88.0,
#                 104.0,
#                 102.0,
#                 73.0,
#                 91.0,
#                 100.0,
#                 97.0,
#                 122.0,
#                 103.0,
#                 154.0,
#                 156.0,
#                 207.0,
#                 229.0,
#                 328.0,
#                 364.0,
#                 353.0,
#                 302.0,
#                 256.0,
#                 278.0,
#                 310.0,
#                 275.0,
#                 271.0,
#                 261.0,
#                 312.0,
#                 309.0,
#                 242.0,
#                 226.0,
#                 232.0,
#                 195.0,
#                 173.0,
#                 171.0,
#                 185.0,
#                 150.0,
#                 122.0,
#                 184.0,
#                 155.0,
#                 160.0,
#                 167.0,
#                 165.0,
#                 153.0,
#                 149.0,
#                 134.0,

# %% [markdown]
# ## 8. 一些特殊的名字

# %%
class Solution:
    # @return a string
    def getlongestpalindrome(self, s, l, r):
        while l >= 0 and r < len(s) and s[l] == s[r]:
            l -= 1; r += 1
        return s[l+1 : r]
    def longestPalindrome(self, s):
        palindrome = ''
        for i in range(len(s)):
            len1 = len(self.getlongestpalindrome(s, i, i))
            if len1 > len(palindrome): palindrome = self.getlongestpalindrome(s, i, i)
            len2 = len(self.getlongestpalindrome(s, i, i + 1))
            if len2 > len(palindrome): palindrome = self.getlongestpalindrome(s, i, i + 1)
        return True if len(palindrome) > 5 else False

# %%
a = Solution()

# %%
a.longestPalindrome('alfrederfl')
# Out:
# True

# %%
all_name = data['Name'].unique()

# %%
palindrome_name = []
for name in all_name:
    if a.longestPalindrome(name):
        palindrome_name.append(name)

# %%
palindrome_data = data[data['Name'].isin(palindrome_name)].groupby('Name').Count.sum()

# %%
name = list(palindrome_data.index)
value = list(palindrome_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed
wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="d0038fa0362240ef922ff40ce73aeb87" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_d0038fa0362240ef922ff40ce73aeb87 = echarts.init(document.getElementById('d0038fa0362240ef922ff40ce73aeb87'), null, {renderer: 'canvas'});
# var option_d0038fa0362240ef922ff40ce73aeb87 = {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6834959,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Austreberto",
#                     "value": 16.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(14,111,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Barabara",
#                     "value": 181.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,20,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Bareera",
#                     "value": 13.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(33,111,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Bareerah",
#                     "value": 15.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,44,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Basilisa",
#                     "value": 32.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,126,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Brenner",
#                     "value": 1053.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,132,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Channah",
#                     "value": 205.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(134,2,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Dannylynn",
#                     "value": 5.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,89,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Deneene",
#                     "value": 74.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,6,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Drakkar",
#                     "value": 142.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(42,72,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Fredderick",
#                     "value": 134.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(76,29,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Geissie",
#                     "value": 19.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,106,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Glennell",
#                     "value": 17.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,129,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Greggery",
#                     "value": 16.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,49,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Habeeba",
#                     "value": 9.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,4,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Henretter",
#                     "value": 79.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,158,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jaleela",
#                     "value": 5.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,38,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Janellen",
#                     "value": 40.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,79,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jeneene",
#                     "value": 17.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,12,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jennylynn",
#                     "value": 19.0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,39,7)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jhonattan",
#                     "value": 7.0,
#                     "textStyle": {
#                         "normal": {
#                             "color"
