# %%
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
ilun = pd.read_csv('ilun.csv')
ikun = pd.read_csv('ikun.csv')

# %%
ilun['followers_cut'] = pd.cut(ilun['user.followers_count'], 
       [0,10,50,100,500,1000,5000,10000, 50000, 100000, 500000, 1000000, 5000000, 10000000], 
       labels=['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000'],
                    right=False)

ikun['followers_cut'] = pd.cut(ikun['user.followers_count'], 
       [0,10,50,100,500,1000,5000,10000, 50000, 100000, 500000, 1000000, 5000000, 10000000], 
       labels=['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000'],
                    right=False)

# %%
ilun['followers_cut'].sample(10000).value_counts()
# Out:
# 100-500             3498
# 10-50               1819
# 50-100              1683
# 0-10                1594
# 500-1000             728
# 1000-5000            530
# 5000-10000            58
# 10000-50000           57
# 100000-500000         13
# 50000-100000          12
# 1000000-5000000        7
# 500000-1000000         1
# 5000000-10000000       0
# Name: followers_cut, dtype: int64

# %%
from pyecharts import Bar

idx = ['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000']
values = [1594, 1819, 1683, 3498, 728, 530, 58, 57, 12, 13, 1, 7, 0]
bar = Bar("周杰伦新进粉丝的粉丝数分布","单位:人", width = 500,height=500)
bar.add("", idx, values, is_stack=True,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20, 
       is_convert=True, is_yaxis_inverse=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cc7de9a532d64250a3ed7ffd4b855f59" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cc7de9a532d64250a3ed7ffd4b855f59 = echarts.init(document.getElementById('cc7de9a532d64250a3ed7ffd4b855f59'), 'light', {renderer: 'canvas'});
#
# var option_cc7de9a532d64250a3ed7ffd4b855f59 = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26\u65b0\u8fdb\u7c89\u4e1d\u7684\u7c89\u4e1d\u6570\u5206\u5e03",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
ikun['followers_cut'].sample(10000).value_counts()
# Out:
# 0-10                4211
# 100-500             2026
# 10-50               1769
# 50-100              1097
# 500-1000             429
# 1000-5000            368
# 5000-10000            41
# 10000-50000           40
# 100000-500000          8
# 50000-100000           5
# 500000-1000000         4
# 5000000-10000000       1
# 1000000-5000000        1
# Name: followers_cut, dtype: int64

# %%
values = [4211, 1769, 1097, 2026, 429, 368, 41, 40, 5, 8, 4, 1, 1]
bar = Bar("蔡徐坤新进粉丝的粉丝数分布","单位:人", width = 500,height=500)
bar.add("", ikun_follower.index, ikun_follower.values, is_stack=True,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20, 
       is_convert=True, is_yaxis_inverse=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e1ff33ee9881490b89081119cb530183" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e1ff33ee9881490b89081119cb530183 = echarts.init(document.getElementById('e1ff33ee9881490b89081119cb530183'), 'light', {renderer: 'canvas'});
#
# var option_e1ff33ee9881490b89081119cb530183 = {
#     "title": [
#         {
#             "text": "\u8521\u5f90\u5764\u65b0\u8fdb\u7c89\u4e1d\u7684\u7c89\u4e1d\u6570\u5206\u5e03",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
from pyecharts import Bar

idx = ['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000']
values1 = [1594, 1819, 1683, 3498, 728, 530, 58, 57, 12, 13, 1, 7, 0]
values2 = [4211, 1769, 1097, 2026, 429, 368, 41, 40, 5, 8, 4, 1, 1]
bar = Bar("周杰伦/蔡徐坤新进粉丝的粉丝数分布","单位:人", width = 1000,height=500)
bar.add("周杰伦", idx, values1, is_stack=False,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20)
bar.add("蔡徐坤", idx, values2, is_stack=False,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20)  
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8771d015ec374166bb586e417be87e53" style="width:1000px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8771d015ec374166bb586e417be87e53 = echarts.init(document.getElementById('8771d015ec374166bb586e417be87e53'), 'light', {renderer: 'canvas'});
#
# var option_8771d015ec374166bb586e417be87e53 = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26/\u8521\u5f90\u5764\u65b0\u8fdb\u7c89\u4e1d\u7684\u7c89\u4e1d\u6570\u5206\u5e03",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
ilun.columns
# Out:
# Index(['scheme', 'user.id', 'user.screen_name', 'user.verified',
#        'user.verified_type', 'user.verified_type_ext', 'user.followers_count',
#        'user.mbtype', 'user.mbrank', 'user.friends_count', 'desc1',
#        'followers_cut'],
#       dtype='object')

# %%
ilun['friends_cut'] = pd.cut(ilun['user.friends_count'], 
       [0,10,50,100,500,1000,5000,10000, 50000, 100000, 500000, 1000000, 5000000, 10000000], 
       labels=['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000'],
                    right=False)

ikun['friends_cut'] = pd.cut(ikun['user.friends_count'], 
       [0,10,50,100,500,1000,5000,10000, 50000, 100000, 500000, 1000000, 5000000, 10000000], 
       labels=['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000'],
                    right=False)

# %%
ilun['friends_cut'].sample(10000).value_counts()
# Out:
# 100-500             5551
# 50-100              1458
# 500-1000            1055
# 10-50                992
# 0-10                 716
# 1000-5000            226
# 5000-10000             2
# 5000000-10000000       0
# 1000000-5000000        0
# 500000-1000000         0
# 100000-500000          0
# 50000-100000           0
# 10000-50000            0
# Name: friends_cut, dtype: int64

# %%
from pyecharts import Bar

idx = ['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000']
values = [716, 992, 1458, 5551, 1055, 226, 2, 0, 0, 0, 0, 0, 0]
bar = Bar("周杰伦新进粉丝的关注数分布","单位:人", width = 500,height=500)
bar.add("", idx, values, is_stack=True,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20, 
       is_convert=True, is_yaxis_inverse=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9dd94990b0da4401a004992d2ddcf18f" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9dd94990b0da4401a004992d2ddcf18f = echarts.init(document.getElementById('9dd94990b0da4401a004992d2ddcf18f'), 'light', {renderer: 'canvas'});
#
# var option_9dd94990b0da4401a004992d2ddcf18f = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26\u65b0\u8fdb\u7c89\u4e1d\u7684\u5173\u6ce8\u6570\u5206\u5e03",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
ikun['friends_cut'].sample(10000).value_counts()
# Out:
# 100-500             3869
# 10-50               2003
# 50-100              1668
# 0-10                1594
# 500-1000             695
# 1000-5000            171
# 5000000-10000000       0
# 1000000-5000000        0
# 500000-1000000         0
# 100000-500000          0
# 50000-100000           0
# 10000-50000            0
# 5000-10000             0
# Name: friends_cut, dtype: int64

# %%
idx = ['0-10', '10-50', '50-100', '100-500', '500-1000', '1000-5000',
              '5000-10000', '10000-50000', '50000-100000', '100000-500000', 
               '500000-1000000', '1000000-5000000', '5000000-10000000']
values = [1594, 2003, 1668, 3869, 695, 171, 0, 0, 0, 0, 0, 0, 0]
bar = Bar("蔡徐坤新进粉丝的关注数分布","单位:人", width = 500,height=500)
bar.add("", idx, values, is_stack=True,bar_category_gap='40%', 
       xaxis_label_textsize=20, yaxis_label_textsize=20, 
       is_convert=True, is_yaxis_inverse=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1d7f1fcf719b400aa338bed691ea8ca2" style="width:500px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1d7f1fcf719b400aa338bed691ea8ca2 = echarts.init(document.getElementById('1d7f1fcf719b400aa338bed691ea8ca2'), 'light', {renderer: 'canvas'});
#
# var option_1d7f1fcf719b400aa338bed691ea8ca2 = {
#     "title": [
#         {
#             "text": "\u8521\u5f90\u5764\u65b0\u8fdb\u7c89\u4e1d\u7684\u5173\u6ce8\u6570\u5206\u5e03",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %% [markdown]
# ### 粉丝会员等级

# %%
ilun['user.mbrank'].sample(10000).value_counts()
# Out:
# 0    7002
# 1    1529
# 2     382
# 6     283
# 5     281
# 4     264
# 3     223
# 7      36
# Name: user.mbrank, dtype: int64

# %%
ikun['user.mbrank'].sample(10000).value_counts()
# Out:
# 0    7727
# 1    1242
# 2     294
# 6     185
# 4     182
# 5     180
# 3     177
# 7      13
# Name: user.mbrank, dtype: int64

# %%
idx = list(range(0,8))
values1 = [7002, 1529, 382, 223, 264, 281, 283, 36]
values2 = [7727, 1242, 292, 177, 182, 180, 185, 13]
bar = Bar("周杰伦/蔡徐坤超话新进粉丝的微博会员等级分布图","单位:人", width = 650,height=500)
bar.add("周杰伦", idx, values1, is_stack=False,bar_category_gap='40%', label_color=['#3488DB'],
       xaxis_label_textsize=20, yaxis_label_textsize=20, is_label_show=True, legend_top="8%")
bar.add("蔡徐坤", idx, values2, is_stack=False,bar_category_gap='40%', label_color=['#FF6B6B'],
       xaxis_label_textsize=20, yaxis_label_textsize=20, is_label_show=True, legend_top="8%")  
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e1b0d079aaf5412da0b231e916506fe5" style="width:650px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e1b0d079aaf5412da0b231e916506fe5 = echarts.init(document.getElementById('e1b0d079aaf5412da0b231e916506fe5'), 'light', {renderer: 'canvas'});
#
# var option_e1b0d079aaf5412da0b231e916506fe5 = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26/\u8521\u5f90\u5764\u8d85\u8bdd\u65b0\u8fdb\u7c89\u4e1d\u7684\u5fae\u535a\u4f1a\u5458\u7b49\u7ea7\u5206\u5e03\u56fe",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
# ...

# %% [markdown]
# ### 粉丝是否认证

# %%
ilun['user.verified'].sample(20000).value_counts()
# Out:
# False    19575
# True       425
# Name: user.verified, dtype: int64

# %%
ikun['user.verified'].sample(10000).value_counts()
# Out:
# False    9824
# True      176
# Name: user.verified, dtype: int64

# %% [markdown]
# ### 词云图

# %%
import jieba
from collections import Counter
from pyecharts import WordCloud

swords = [x.strip() for x in open ('/home/kesci/input/JayZhou6746/stopwords.txt')]

# %%
def plot_word_cloud(data, swords):
    text = ''.join(data)
    words = list(jieba.cut(text))
    ex_sw_words = []
    for word in words:
        if len(word)>1 and (word not in swords):
            ex_sw_words.append(word)
    c = Counter()
    c = Counter(ex_sw_words)
    wc_data = pd.DataFrame({'word':list(c.keys()), 'counts':list(c.values())}).sort_values(by='counts', ascending=False).head(100)
    wordcloud = WordCloud(width=1300, height=620)
    wordcloud.add("", wc_data['word'], wc_data['counts'], word_size_range=[20, 100])
    return wordcloud

# %%
plot_word_cloud(ilun.loc[ilun['desc1'].notnull(), 'desc1'], swords)
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.921 seconds.
# DEBUG:jieba:Loading model cost 0.921 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="cc4ce48c7cbd44c293757812d5749748" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_cc4ce48c7cbd44c293757812d5749748 = echarts.init(document.getElementById('cc4ce48c7cbd44c293757812d5749748'), 'light', {renderer: 'canvas'});
#
# var option_cc4ce48c7cbd44c293757812d5749748 = {
# ...

# %%
jieba.add_word('蔡徐坤')
plot_word_cloud(ikun.loc[ikun['desc1'].notnull(), 'desc1'], swords)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="35bbf9f2b60a48659ae827c9a8e283ea" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_35bbf9f2b60a48659ae827c9a8e283ea = echarts.init(document.getElementById('35bbf9f2b60a48659ae827c9a8e283ea'), 'light', {renderer: 'canvas'});
#
# var option_35bbf9f2b60a48659ae827c9a8e283ea = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %% [markdown]
# ### 粉丝年龄层分布

# %%
jay = pd.read_csv('/home/kesci/input/JayZhou6746/jay2.csv')

# %%
jay.sample(5)
# Out:
#              uid           昵称    大学   高中   公司 性别 感情状况    所在地        注册时间  \
# 5320  2211242607        腾爷阿修罗   NaN  NaN  NaN  男  NaN  广东 深圳  2011-07-01
# 7391  2946986775      Be-Rj瑞金   NaN  NaN  NaN  男  NaN  广东 广州  2012-09-12
# 6837  2709834623     吹牛b表演艺术家   NaN  NaN  NaN  男  NaN  湖北 武汉  2012-04-16
# 3657  1919267484  17princess1  云南大学  NaN  NaN  女  NaN  海外 美国  2011-01-14
# 2706  1826339901       白白举了个缸   NaN  NaN  NaN  女  NaN  山东 青岛  2010-10-05
#
#                    生日                    简介
# 5320  1990-06-10  双子座                  暂无简介
# 7391  1993-09-14  处女座  从未像现在这么自在，用安静的心好好做点事
# 6837              NaN              非物质文化传承人
# 3657       07-27  狮子座
# 2706  1992-12-31  摩羯座                  暂无简介

# %%
status = jay['感情状况'].value_counts()
status
# Out:
# 单身     213
# 恋爱中     57
# 已婚      44
# 求交往     17
# 丧偶      12
# 订婚       3
# 分居       2
# 离异       1
# 暧昧中      1
# Name: 感情状况, dtype: int64

# %%
from pyecharts import Funnel


funnel = Funnel("周杰伦粉丝感情状况")
funnel.add(
    "",
    status.index,
    status.values,
    is_label_show=True,
    label_pos="inside",
    label_text_color="#fff",
    legend_top="5%"
)
funnel
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="447a7f9d4d3a4e63908d8290b522fac9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_447a7f9d4d3a4e63908d8290b522fac9 = echarts.init(document.getElementById('447a7f9d4d3a4e63908d8290b522fac9'), 'light', {renderer: 'canvas'});
#
# var option_447a7f9d4d3a4e63908d8290b522fac9 = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26\u7c89\u4e1d\u611f\u60c5\u72b6\u51b5",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
univ = jay['大学'].value_counts()

# %%
wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", univ.index, univ.values, word_size_range=[0, 80])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="c9f5acc47f3d4a7892aa6e668d4cd6d5" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_c9f5acc47f3d4a7892aa6e668d4cd6d5 = echarts.init(document.getElementById('c9f5acc47f3d4a7892aa6e668d4cd6d5'), 'light', {renderer: 'canvas'});
#
# var option_c9f5acc47f3d4a7892aa6e668d4cd6d5 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
jay['公司'].unique()
# Out:
# array([nan, 'chant', '上海通用汽车有限公司', '完美世界（北京）软件有限公司', '本来生活网', '北海',
#        '折磨你的鸟不拉屎-TU', '自由职业', '阿里巴巴', '家里蹲坑大学', '德昌电机', '锐特信息', 'C4',
#        '郁金香广告传播有限公司', 'DCITS', '北京天坛医院', 'Microsoft', '绍兴银行', '肌肉工作室',
#        '宜家（中国）投资有限公司', 'CMCC', '云南电视台', '联想移动通信科技有限公司', '海正药业（杭州）有限公司',
#        '编辑', 'BOSCH', '无', '优酷网', '广东松山职业技术学院', '麦包包', '易车',
#        'CardinalHealth', '意大利帕尔马市法院', '阿呆呆幼稚园', '树洞研究所', '大众点评网',
#        '林文学装饰工程有限公司', '北京铁路局', '浙江小百花越剧团', '深圳市蓝凌软件股份有限公司', '德力西电气有限公司',
#        'SVW', '延广交通文艺台',
#        'Department of International Magical Cooperation',
#        '浙江天使之泪珍珠股份有限公司', '新华社·新华网', '转向器有限公司', '国家电网公司', '小小小私企', 'H',
#        '财新传媒有限公司', '邮政储蓄银行', 'sweet icing工作室', '筑道设计', '仁济医院',
#        'U-moment婚礼工作室', '永恒影像', 'Modern Water Inc', '易简设计', '工作室',
#        '白日梦无限公司', '湖南永通集团', '索尼', '交通银行股份有限公司', '湖北三环海通汽车有限公司', '琼州学院',
#        'shiatzy chen', '中信证券', 'GE', '小学', '扬州市江都区人力资源和社会保障局',
#        '博士视听系统(上海）有限公司', '你猜', '北京博润兄弟管理顾问有限公司', '创昱达', '海南广播电视总台',
# ...

# %%
jay['province'] = jay['所在地'].str.split(' ', expand=True)[0]
jay['city'] = jay['所在地'].str.split(' ', expand=True)[1]

# %%
jay['birthday'] = jay['生日'].str.extract(r'(\d{4}-\d{2}-\d{2})')
jay['const'] = jay['生日'].str.extract(r'(\w{2}座)')

# %%
jay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8756 entries, 0 to 8755
# Data columns (total 15 columns):
# uid         8756 non-null object
# 昵称          8716 non-null object
# 大学          2340 non-null object
# 高中          855 non-null object
# 公司          885 non-null object
# 性别          8718 non-null object
# 感情状况        350 non-null object
# 所在地         8716 non-null object
# 注册时间        8708 non-null object
# 生日          6917 non-null object
# 简介          8726 non-null object
# province    8716 non-null object
# city        6523 non-null object
# birthday    4025 non-null object
# const       6848 non-null object
# dtypes: object(15)
# memory usage: 1.0+ MB

# %%
jay['birthday'].sample(5)
# Out:
# 1674    1992-03-28
# 4330           NaN
# 5730    1998-03-29
# 7746           NaN
# 8012    1996-02-24
# Name: birthday, dtype: object

# %%
jay['注册时间'] = pd.to_datetime(jay['注册时间'], errors='coerce')
jay['birthday'] = pd.to_datetime(jay['birthday'], errors='coerce')

# %%
register = jay['注册时间'].dt.year.value_counts()
register
# Out:
# 2011.0    3144
# 2010.0    2773
# 2012.0    1611
# 2013.0     852
# 2009.0     182
# 2014.0     141
# 2015.0       4
# 2017.0       1
# Name: 注册时间, dtype: int64

# %%
bar = Bar("周杰伦超话粉丝注册微博时间", "单位:人", width=700, height=500)
bar.add("",
        [2009, 2010, 2011, 2012, 2013, 2014, 2015],
        [182, 2773, 3144, 1611, 852, 141, 4],
        is_stack=False, bar_category_gap='40%',
        xaxis_label_textsize=20, yaxis_label_textsize=20,
        label_color=['#FF6B6B'])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d3cf98c8b8c44cc28f5093fd0adeb662" style="width:700px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d3cf98c8b8c44cc28f5093fd0adeb662 = echarts.init(document.getElementById('d3cf98c8b8c44cc28f5093fd0adeb662'), 'light', {renderer: 'canvas'});
#
# var option_d3cf98c8b8c44cc28f5093fd0adeb662 = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26\u8d85\u8bdd\u7c89\u4e1d\u6ce8\u518c\u5fae\u535a\u65f6\u95f4",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
# ...

# %%
jay['bir_year'] = jay['birthday'].dt.year

# %%
bir_year = jay.loc[(jay['bir_year'] > 1970)&(jay['bir_year']<2010), 'bir_year'].value_counts().sort_index()

# %%
bar = Bar("周杰伦超话粉丝年龄层", "单位:人", width=700, height=500)
bar.add("",
        bir_year.index,
        bir_year.values,
        is_stack=False, bar_category_gap='40%',
        xaxis_label_textsize=20, yaxis_label_textsize=20,
        label_color=['#FF6B6B'])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8b11275fb02f47bfb561ca4d0fe8813a" style="width:700px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8b11275fb02f47bfb561ca4d0fe8813a = echarts.init(document.getElementById('8b11275fb02f47bfb561ca4d0fe8813a'), 'light', {renderer: 'canvas'});
#
# var option_8b11275fb02f47bfb561ca4d0fe8813a = {
#     "title": [
#         {
#             "text": "\u5468\u6770\u4f26\u8d85\u8bdd\u7c89\u4e1d\u5e74\u9f84\u5c42",
#             "subtext": "\u5355\u4f4d:\u4eba",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...
